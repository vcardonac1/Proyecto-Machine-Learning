# %%
import os
import pandas as pd
import cv2
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import reuters
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, MaxPooling2D, Conv2D, Flatten, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import matplotlib.image as img
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.utils import shuffle

from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, make_scorer

# %%
#observamos las imágenes
plt.subplot(1, 2, 1)
plt.title('Label Negativo: 0')
plt.imshow(cv2.imread('data\\images\\image_1054.jpg'))

plt.subplot(1, 2, 2)
plt.title('Label Positivo: 1')
plt.imshow(cv2.imread('data\\images\\image_13.jpg'))

plt.show()

# %% [markdown]
# ## Pre-procesamiento de los Datos
# Unir en un solo dataset las imagenes con sus labels

# %%
df = pd.read_csv('data\\labels.txt', sep=" ", header = None)
df.columns =['filepaths', 'labels']
df.head()
# Out:
#                       filepaths  labels
# 0  data/images/image_189342.jpg       0
# 1  data/images/image_145102.jpg       0
# 2   data/images/image_31546.jpg       0
# 3  data/images/image_441280.jpg       1
# 4  data/images/image_215578.jpg       0

# %%
labels_0 = df.loc[df['labels'] == 0]
labels_1 = df.loc[df['labels'] == 1]
labels_0 = labels_0[0:len(labels_1)]
labels = [labels_0, labels_1]
df2 = pd.concat(labels)
df = df2
df = shuffle(df).reset_index(drop = True)
print (df['labels'].value_counts())
# Out:
# 1    1351
# 0    1351
# Name: labels, dtype: int64

# %%
# Se separan los datos en training, validacion y test
X_train, X_test, y_train, y_test = train_test_split(df['filepaths'], df['labels'], test_size=0.30, random_state=33)
X_test, X_val, y_test, y_val= train_test_split(X_test, y_test, train_size=0.5, random_state=34)

print('Cantidad de datos en cada set\n')
print('Training:', len(y_train), '\t\t0:', y_train.value_counts()[0],', 1:' ,y_train.value_counts()[1])
print('Validacion:', len(y_val), '\t0:', y_val.value_counts()[0],', 1:' ,y_val.value_counts()[1])
print('Test:', len(y_test), '\t\t0:', y_test.value_counts()[0],', 1:' ,y_test.value_counts()[1])
# Out:
# Cantidad de datos en cada set
#
# Training: 1891 		0: 948 , 1: 943
# Validacion: 406 	0: 205 , 1: 201
# Test: 405 		0: 198 , 1: 207

# %% [markdown]
# ## Pre-procesamiento de las imagenes

# %%
IMG_SIZE = 50

def preprocessig_data(data):
    X = []
    for img_path in data:
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY) # Pasamos la imagen a escala de grises
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))/255.0 # normalizamos los pixeles de la imagen
        X.append(img)
    X = np.array(X)
    X = X.reshape((-1, IMG_SIZE, IMG_SIZE, 1)) #Hacemos un reshape de las imagenes
    return X

X_train = preprocessig_data(X_train)
X_val = preprocessig_data(X_val)

# %%
# Usamos labelEncoder para manejar los labels como numeros
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_val = le.transform(y_val)

# %% [markdown]
# ## Red convolucional de al menos 3 capas convolucionales

# %%
model_base = tf.keras.models.Sequential([
  
  Conv2D(20, kernel_size= (3,3), activation='relu', input_shape =(IMG_SIZE,IMG_SIZE,1)),
  MaxPooling2D(),

  Conv2D(40, kernel_size = (3,3), activation='relu'),
  MaxPooling2D(),

  Conv2D(60, kernel_size = (3,3), activation='relu'),
  MaxPooling2D(),
  
  Flatten(),
  Dense(100, activation='relu'),
  Dropout(0.2),
  
  Dense(1, activation= 'sigmoid') # Se tienen 2 posibles clases
])

callbacks = [
    ModelCheckpoint(
    filepath="modelos/checkpoint_model3a",
    save_best_only=True,
    monitor="val_loss")
]

model_base.compile(optimizer='RMSprop',loss=tf.keras.losses.BinaryCrossentropy(from_logits=False), metrics=['Precision', 'Recall'])
model_base.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 20)        200
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 20)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 22, 22, 40)        7240
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 40)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 9, 9, 60)          21660
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 60)         0
#  2D)
#
#  flatten (Flatten)           (None, 960)               0
#
#  dense (Dense)               (None, 100)               96100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 125,301
# Trainable params: 125,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_base = model_base.fit(X_train, y_train, validation_data= (X_val, y_val), batch_size=40, epochs = 200, callbacks=callbacks)
# Out:
# Epoch 1/200
# 47/48 [============================>.] - ETA: 0s - loss: 0.6332 - precision: 0.6303 - recall: 0.7097
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelos\checkpoint_model3a\assets
# INFO:tensorflow:Assets written to: modelos\checkpoint_model3a\assets
# 48/48 [==============================] - 8s 120ms/step - loss: 0.6322 - precision: 0.6317 - recall: 0.7094 - val_loss: 0.5988 - val_precision: 0.6106 - val_recall: 0.9204
# Epoch 2/200
# 47/48 [============================>.] - ETA: 0s - loss: 0.5375 - precision: 0.7391 - recall: 0.7439
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelos\checkpoint_model3a\assets
# INFO:tensorflow:Assets written to: modelos\checkpoint_model3a\assets
# 48/48 [==============================] - 5s 112ms/step - loss: 0.5360 - precision: 0.7408 - recall: 0.7455 - val_loss: 0.4786 - val_precision: 0.7789 - val_recall: 0.7711
# Epoch 3/200
# 48/48 [==============================] - 4s 84ms/step - loss: 0.4798 - precision: 0.7838 - recall: 0.7922 - val_loss: 0.4826 - val_precision: 0.8750 - val_recall: 0.6269
# Epoch 4/200
# 48/48 [==============================] - 4s 82ms/step - loss: 0.4357 - precision: 0.8089 - recall: 0.8123 - val_loss: 0.8007 - val_precision: 0.9310 - val_recall: 0.2687
# Epoch 5/200
# 47/48 [============================>.] - ETA: 0s - loss: 0.4084 - precision: 0.8287 - recall: 0.8278
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelos\checkpoint_model3a\assets
# INFO:tensorflow:Assets written to: modelos\checkpoint_model3a\assets
# 48/48 [==============================] - 6s 116ms/step - loss: 0.4077 - precision: 0.8280 - recall: 0.8271 - val_loss: 0.4576 - val_precision: 0.8993 - val_recall: 0.6219
# Epoch 6/200
# 47/48 [============================>.] - ETA: 0s - loss: 0.3543 - precision: 0.8598 - recall: 0.8415
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelos\checkpoint_model3a\assets
# INFO:tensorflow:Assets written to: modelos\checkpoint_model3a\assets
# 48/48 [==============================] - 6s 127ms/step - loss: 0.3528 - precision: 0.8602 - recall: 0.8420 - val_loss: 0.4069 - val_precision: 0.8486 - val_recall: 0.7811
# Epoch 7/200
# 48/48 [==============================] - 4s 85ms/step - loss: 0.3373 - precision: 0.8626 - recall: 0.8590 - val_loss: 0.5026 - val_precision: 0.9065 - val_recall: 0.6269
# Epoch 8/200
# 47/48 [============================>.] - ETA: 0s - loss: 0.3031 - precision: 0.8788 - recall: 0.8657
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelos\checkpoint_model3a\assets
# INFO:tensorflow:Assets written to: modelos\checkpoint_model3a\assets
# 48/48 [==============================] - 5s 108ms/step - loss: 0.3030 - precision: 0.8793 - recall: 0.8653 - val_loss: 0.3632 - val_precision: 0.8398 - val_recall: 0.8607
# Epoch 9/200
# 48/48 [==============================] - 3s 68ms/step - loss: 0.2853 - precision: 0.8903 - recall: 0.8780 - val_loss: 0.3732 - val_precision: 0.8542 - val_recall: 0.8159
# Epoch 10/200
# 48/48 [==============================] - 3s 69ms/step - loss: 0.2612 - precision: 0.8996 - recall: 0.8929 - val_loss: 0.4144 - val_precision: 0.8931 - val_recall: 0.7065
# Epoch 11/200
# 48/48 [==============================] - 3s 68ms/step - loss: 0.2281 - precision: 0.9185 - recall: 0.9077 - val_loss: 0.5162 - val_precision: 0.7461 - val_recall: 0.9502
# Epoch 12/200
# 48/48 [==============================] - 3s 73ms/step - loss: 0.2171 - precision: 0.9175 - recall: 0.9205 - val_loss: 0.4004 - val_precision: 0.8502 - val_recall: 0.8756
# Epoch 13/200
# 48/48 [==============================] - 3s 69ms/step - loss: 0.1901 - precision: 0.9280 - recall: 0.9300 - val_loss: 0.4283 - val_precision: 0.8852 - val_recall: 0.8060
# Epoch 14/200
# 48/48 [==============================] - 3s 66ms/step - loss: 0.1757 - precision: 0.9331 - recall: 0.9321 - val_loss: 0.4983 - val_precision: 0.7652 - val_recall: 0.9403
# Epoch 15/200
# 48/48 [==============================] - 3s 71ms/step - loss: 0.1548 - precision: 0.9379 - recall: 0.9449 - val_loss: 0.6037 - val_precision: 0.7405 - val_recall: 0.9652
# Epoch 16/200
# 48/48 [==============================] - 3s 70ms/step - loss: 0.1431 - precision: 0.9427 - recall: 0.9417 - val_loss: 0.4010 - val_precision: 0.8585 - val_recall: 0.8756
# Epoch 17/200
# 48/48 [==============================] - 3s 71ms/step - loss: 0.1250 - precision: 0.9537 - recall: 0.9608 - val_loss: 0.4515 - val_precision: 0.7965 - val_recall: 0.9154
# Epoch 18/200
# 48/48 [==============================] - 3s 68ms/step - loss: 0.1073 - precision: 0.9649 - recall: 0.9618 - val_loss: 0.5100 - val_precision: 0.8841 - val_recall: 0.7214
# Epoch 19/200
# 48/48 [==============================] - 3s 67ms/step - loss: 0.1031 - precision: 0.9578 - recall: 0.9629 - val_loss: 0.5838 - val_precision: 0.7705 - val_recall: 0.9353
# Epoch 20/200
# 48/48 [==============================] - 4s 80ms/step - loss: 0.0832 - precision: 0.9642 - recall: 0.9703 - val_loss: 0.4578 - val_precision: 0.8349 - val_recall: 0.9055
# Epoch 21/200
# 48/48 [==============================] - 4s 79ms/step - loss: 0.0709 - precision: 0.9717 - recall: 0.9830 - val_loss: 0.6106 - val_precision: 0.7957 - val_recall: 0.9303
-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.9455 - val_precision: 0.8073 - val_recall: 0.8756
# Epoch 73/200
# 48/48 [==============================] - 3s 73ms/step - loss: 0.0080 - precision: 0.9968 - recall: 0.9979 - val_loss: 1.5135 - val_precision: 0.8326 - val_recall: 0.8905
# Epoch 74/200
# 48/48 [==============================] - 4s 75ms/step - loss: 0.0022 - precision: 0.9989 - recall: 1.0000 - val_loss: 1.7621 - val_precision: 0.8279 - val_recall: 0.8856
# Epoch 75/200
# 48/48 [==============================] - 4s 73ms/step - loss: 0.0056 - precision: 0.9968 - recall: 1.0000 - val_loss: 1.7275 - val_precision: 0.8295 - val_recall: 0.8955
# Epoch 76/200
# 48/48 [==============================] - 4s 75ms/step - loss: 0.0049 - precision: 0.9989 - recall: 0.9968 - val_loss: 1.6845 - val_precision: 0.8838 - val_recall: 0.8706
# Epoch 77/200
# 48/48 [==============================] - 4s 73ms/step - loss: 0.0150 - precision: 0.9979 - recall: 0.9979 - val_loss: 1.4476 - val_precision: 0.8700 - val_recall: 0.8657
# Epoch 78/200
# 48/48 [==============================] - 3s 72ms/step - loss: 0.0031 - precision: 0.9979 - recall: 1.0000 - val_loss: 1.6352 - val_precision: 0.8476 - val_recall: 0.8856
# Epoch 79/200
# 48/48 [==============================] - 4s 75ms/step - loss: 3.5017e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7939 - val_precision: 0.8227 - val_recall: 0.9005
# Epoch 80/200
# 48/48 [==============================] - 4s 75ms/step - loss: 0.0106 - precision: 0.9947 - recall: 0.9947 - val_loss: 1.6917 - val_precision: 0.8529 - val_recall: 0.8657
# Epoch 81/200
# 48/48 [==============================] - 4s 77ms/step - loss: 0.0115 - precision: 0.9968 - recall: 0.9968 - val_loss: 1.6115 - val_precision: 0.8387 - val_recall: 0.9055
# Epoch 82/200
# 48/48 [==============================] - 3s 71ms/step - loss: 1.6602e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.8253 - val_precision: 0.8380 - val_recall: 0.9005
# Epoch 83/200
# 48/48 [==============================] - 3s 73ms/step - loss: 0.0027 - precision: 0.9989 - recall: 0.9989 - val_loss: 1.4487 - val_precision: 0.8737 - val_recall: 0.8607
# Epoch 84/200
# 48/48 [==============================] - 4s 74ms/step - loss: 0.0155 - precision: 0.9968 - recall: 0.9947 - val_loss: 1.9211 - val_precision: 0.8026 - val_recall: 0.9104
# Epoch 85/200
# 48/48 [==============================] - 3s 73ms/step - loss: 0.0044 - precision: 0.9989 - recall: 0.9979 - val_loss: 1.5389 - val_precision: 0.8443 - val_recall: 0.8905
# Epoch 86/200
# 48/48 [==============================] - 3s 70ms/step - loss: 0.0049 - precision: 0.9979 - recall: 1.0000 - val_loss: 1.6217 - val_precision: 0.8794 - val_recall: 0.8706
# Epoch 87/200
# 48/48 [==============================] - 3s 70ms/step - loss: 0.0102 - precision: 0.9989 - recall: 0.9979 - val_loss: 1.5220 - val_precision: 0.8287 - val_recall: 0.8905
# Epoch 88/200
# 48/48 [==============================] - 3s 72ms/step - loss: 3.8223e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 1
-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.9835 - val_precision: 0.8406 - val_recall: 0.8657
# Epoch 124/200
# 48/48 [==============================] - 4s 81ms/step - loss: 0.0090 - precision: 0.9979 - recall: 0.9979 - val_loss: 2.5265 - val_precision: 0.8117 - val_recall: 0.9005
# Epoch 125/200
# 48/48 [==============================] - 4s 87ms/step - loss: 0.0103 - precision: 0.9968 - recall: 0.9979 - val_loss: 1.9729 - val_precision: 0.8125 - val_recall: 0.9055
# Epoch 126/200
# 48/48 [==============================] - 4s 88ms/step - loss: 1.3361e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.8913 - val_precision: 0.8750 - val_recall: 0.8358
# Epoch 127/200
# 48/48 [==============================] - 4s 82ms/step - loss: 0.0010 - precision: 1.0000 - recall: 0.9989 - val_loss: 1.7926 - val_precision: 0.8406 - val_recall: 0.8657
# Epoch 128/200
# 48/48 [==============================] - 4s 84ms/step - loss: 0.0084 - precision: 0.9979 - recall: 0.9947 - val_loss: 1.7752 - val_precision: 0.8477 - val_recall: 0.8308
# Epoch 129/200
# 48/48 [==============================] - 4s 77ms/step - loss: 1.0511e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.0021 - val_precision: 0.8317 - val_recall: 0.8607
# Epoch 130/200
# 48/48 [==============================] - 4s 83ms/step - loss: 4.5073e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.0877 - val_precision: 0.8564 - val_recall: 0.8607
# Epoch 131/200
# 48/48 [==============================] - 4s 79ms/step - loss: 0.0061 - precision: 0.9989 - recall: 0.9979 - val_loss: 2.1028 - val_precision: 0.8178 - val_recall: 0.8706
# Epoch 132/200
# 48/48 [==============================] - 4s 79ms/step - loss: 4.3943e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.1526 - val_precision: 0.8349 - val_recall: 0.8806
# Epoch 133/200
# 48/48 [==============================] - 4s 74ms/step - loss: 0.0011 - precision: 0.9989 - recall: 1.0000 - val_loss: 1.9541 - val_precision: 0.8358 - val_recall: 0.8358
# Epoch 134/200
# 48/48 [==============================] - 4s 76ms/step - loss: 6.0008e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.3537 - val_precision: 0.8279 - val_recall: 0.8856
# Epoch 135/200
# 48/48 [==============================] - 4s 77ms/step - loss: 0.0031 - precision: 0.9989 - recall: 1.0000 - val_loss: 2.2441 - val_precision: 0.8301 - val_recall: 0.8507
# Epoch 136/200
# 48/48 [==============================] - 4s 76ms/step - loss: 0.0120 - precision: 0.9968 - recall: 0.9958 - val_loss: 2.2864 - val_precision: 0.8145 - val_recall: 0.8955
# Epoch 137/200
# 48/48 [==============================] - 4s 79ms/step - loss: 0.0048 - precision: 0.9979 - recall: 1.0000 - val_loss: 2.0924 - val_precision: 0.8564 - val_recall: 0.8308
# Epoch 138/200
# 48/48 [==============================] - 4s 82ms/step - loss: 0.0028 - precision: 1.0000 - recall: 0.9989 - val_loss: 1.9616 - val_precision: 0.8241 - val_recall: 0.8856
# Epoch 139/200
# 48/48 [==============================] - 4s 78ms/step - loss: 0.0077 - precision: 0.9979 - recall: 0.9989 - val_loss: 2.6253 - val_precision: 0.7946 - val_recall: 0.8856
# Epoch 140/200
# 48/48 [==============================] - 4s 79ms/step - loss: 3.8146e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.3066 - val_precision: 0.8169 - val_recall: 0.8657
# Epoch 141/200
# 48/48 [==============================] - 4s 82ms/step - loss: 2.6847e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.5796 - val_precision: 0.8333 - val_recall: 0.8458
# Epoch 142/200
# 48/48 [==============================] - 4s 76ms/step - loss: 0.0063 - precision: 0.9989 - recall: 0.9968 - val_loss: 2.3388 - val_precision: 0.8054 - val_recall: 0.8856
# Epoch 143/200
# 48/48 [==============================] - 4s 74ms/step - loss: 2.8993e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.3257 - val_precision: 0.8100 - val_recall: 0.8905
# Epoch 144/200
# 48/48 [==============================] - 3s 71ms/step - loss: 5.2431e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.5606 - val_precision: 0.8373 - val_recall: 0.8706
# Epoch 145/200
# 48/48 [==============================] - 3s 73ms/step - loss: 0.0028 - precision: 0.9979 - recall: 1.0000 - val_loss: 2.7519 - val_precision: 0.8157 - val_recall: 0.8806
# Epoch 146/200
# 48/48 [==============================] - 4s 74ms/step - loss: 0.0012 - precision: 1.0000 - recall: 0.9989 - val_loss: 2.4625 - val_precision: 0.8310 - val_recall: 0.8806
# Epoch 147/200
# 48/48 [==============================] - 4s 84ms/step - loss: 3.3795e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4240 - val_precision: 0.8301 - val_recall: 0.8507
# Epoch 148/200
# 48/48 [==============================] - 4s 77ms/step - loss: 0.0165 - precision: 0.9989 - recall: 0.9979 - val_loss: 2.6975 - val_precision: 0.8287 - val_recall: 0.8905
# Epoch 149/200
# 48/48 [==============================] - 4s 80ms/step - loss: 9.2440e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.6342 - val_precision: 0.8357 - val_recall: 0.8607
# Epoch 150/200
# 48/48 [==============================] - 4s 76ms/step - loss: 0.0135 - precision: 0.9968 - recall: 0.9979 - val_loss: 2.4045 - val_precision: 0.8382 - val_recall: 0.8507
# Epoch 151/200
# 48/48 [==============================] - 4s 77ms/step - loss: 7.9137e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.3746 - val_precision: 0.8309 - val_recall: 0.8557
# Epoch 152/200
# 48/48 [==============================] - 4s 74ms/step - loss: 4.2357e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4726 - val_precision: 0.8165 - val_recall: 0.8856
# Epoch 153/200
# 48/48 [==============================] - 4s 73ms/step - loss: 6.6103e-04 - precision: 0.9989 - recall: 1.0000 - val_loss: 2.4246 - val_precision: 0.8119 - val_recall: 0.8806
# Epoch 154/200
# 48/48 [==============================] - 4s 76ms/step - loss: 5.2862e-04 - precision: 0.9989 - recall: 1.0000 - val_loss: 2.4807 - val_precision: 0.8528 - val_recall: 0.8358
# Epoch 155/200
# 48/48 [==============================] - 3s 72ms/step - loss: 5.5983e-04 - precision: 1.0000 - recall: 0.9989 - val_loss: 2.7274 - val_precision: 0.8211 - val_recall: 0.8905
# Epoch 156/200
# 48/48 [==============================] - 4s 75ms/step - loss: 3.6854e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2966 - val_precision: 0.8607 - val_recall: 0.8607
# Epoch 157/200
# 48/48 [==============================] - 4s 74ms/step - loss: 7.8359e-04 - precision: 1.0000 - recall: 0.9989 - val_loss: 2.2720 - val_precision: 0.8326 - val_recall: 0.8905
# Epoch 158/200
# 48/48 [==============================] - 4s 79ms/step - loss: 0.0016 - precision: 0.9989 - recall: 1.0000 - val_loss: 2.4937 - val_precision: 0.9045 - val_recall: 0.8010
# Epoch 159/200
# 48/48 [==============================] - 4s 74ms/step - loss: 4.9587e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4837 - val_precision: 0.8219 - val_recall: 0.8955
# Epoch 160/200
# 48/48 [==============================] - 4s 76ms/step - loss: 0.0094 - precision: 0.9989 - recall: 0.9989 - val_loss: 2.5326 - val_precision: 0.8198 - val_recall: 0.9055
# Epoch 161/200
# 48/48 [==============================] - 4s 82ms/step - loss: 0.0085 - precision: 0.9968 - recall: 0.9958 - val_loss: 2.2889 - val_precision: 0.8117 - val_recall: 0.9005
# Epoch 162/200
# 48/48 [==============================] - 4s 78ms/step - loss: 1.1095e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4282 - val_precision: 0.8062 - val_recall: 0.9104
# Epoch 163/200
# 48/48 [==============================] - 4s 80ms/step - loss: 0.0062 - precision: 0.9989 - recall: 0.9968 - val_loss: 2.9469 - val_precision: 0.7965 - val_recall: 0.9154
# Epoch 164/200
# 48/48 [==============================] - 3s 72ms/step - loss: 0.0062 - precision: 0.9979 - recall: 0.9979 - val_loss: 2.7845 - val_precision: 0.7915 - val_recall: 0.9254
# Epoch 165/200
# 48/48 [==============================] - 4s 77ms/step - loss: 4.9021e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2555 - val_precision: 0.8219 - val_recall: 0.8955
# Epoch 166/200
# 48/48 [==============================] - 4s 81ms/step - loss: 3.4488e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.5944 - val_precision: 0.8158 - val_recall: 0.9254
# Epoch 167/200
# 48/48 [==============================] - 4s 77ms/step - loss: 0.0206 - precision: 0.9968 - recall: 0.9979 - val_loss: 2.3911 - val_precision: 0.8265 - val_recall: 0.9005
# Epoch 168/200
# 48/48 [==============================] - 4s 76ms/step - loss: 6.8071e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4327 - val_precision: 0.8259 - val_recall: 0.9204
# Epoch 169/200
# 48/48 [==============================] - 4s 77ms/step - loss: 7.0756e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4222 - val_precision: 0.8288 - val_recall: 0.9154
# Epoch 170/200
# 48/48 [==============================] - 4s 74ms/step - loss: 1.8437e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.0183 - val_precision: 0.7922 - val_recall: 0.9104
# Epoch 171/200
# 48/48 [==============================] - 4s 76ms/step - loss: 0.0058 - precision: 0.9979 - recall: 0.9989 - val_loss: 2.1711 - val_precision: 0.8295 - val_recall: 0.8955
# Epoch 172/200
# 48/48 [==============================] - 4s 79ms/step - loss: 0.0035 - precision: 0.9989 - recall: 0.9979 - val_loss: 2.8545 - val_precision: 0.8265 - val_recall: 0.9005
# Epoch 173/200
# 48/48 [==============================] - 4s 74ms/step - loss: 4.2273e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4286 - val_precision: 0.8578 - val_recall: 0.8706
# Epoch 174/200
# 48/48 [==============================] - 4s 78ms/step - loss: 0.0076 - precision: 0.9979 - recall: 0.9989 - val_loss: 2.3560 - val_precision: 0.8364 - val_recall: 0.9154
# Epoch 175/200
# 48/48 [==============================] - 4s 84ms/step - loss: 0.0076 - precision: 0.9989 - recall: 0.9989 - val_loss: 2.2160 - val_precision: 0.8357 - val_recall: 0.8856
# Epoch 176/200
# 48/48 [==============================] - 4s 80ms/step - loss: 5.7281e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.5599 - val_precision: 0.8178 - val_recall: 0.9154
# Epoch 177/200
# 48/48 [==============================] - 4s 75ms/step - loss: 2.7316e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.3573 - val_precision: 0.8365 - val_recall: 0.8657
# Epoch 178/200
# 48/48 [==============================] - 4s 78ms/step - loss: 0.0202 - precision: 0.9979 - recall: 0.9979 - val_loss: 2.7238 - val_precision: 0.8235 - val_recall: 0.9055
# Epoch 179/200
# 48/48 [==============================] - 4s 74ms/step - loss: 0.0018 - precision: 1.0000 - recall: 0.9989 - val_loss: 2.6904 - val_precision: 0.8421 - val_recall: 0.8756
# Epoch 180/200
# 48/48 [==============================] - 3s 72ms/step - loss: 0.0071 - precision: 0.9989 - recall: 0.9979 - val_loss: 2.5403 - val_precision: 0.8246 - val_recall: 0.8657
# Epoch 181/200
# 48/48 [==============================] - 3s 69ms/step - loss: 1.4535e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.5070 - val_precision: 0.8480 - val_recall: 0.8607
# Epoch 182/200
# 48/48 [==============================] - 3s 72ms/step - loss: 1.3805e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.6572 - val_precision: 0.8265 - val_recall: 0.9005
# Epoch 183/200
# 48/48 [==============================] - 3s 70ms/step - loss: 3.3029e-07 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.6215 - val_precision: 0.8310 - val_recall: 0.8806
# Epoch 184/200
# 48/48 [==============================] - 4s 88ms/step - loss: 0.0032 - precision: 1.0000 - recall: 0.9989 - val_loss: 2.5426 - val_precision: 0.8233 - val_recall: 0.8806
# Epoch 185/200
# 48/48 [==============================] - 4s 81ms/step - loss: 0.0082 - precision: 0.9989 - recall: 1.0000 - val_loss: 2.5556 - val_precision: 0.8364 - val_recall: 0.8905
# Epoch 186/200
# 48/48 [==============================] - 4s 79ms/step - loss: 9.2118e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.3084 - val_precision: 0.8488 - val_recall: 0.8657
# Epoch 187/200
# 48/48 [==============================] - 4s 85ms/step - loss: 1.9464e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.5319 - val_precision: 0.8488 - val_recall: 0.8657
# Epoch 188/200
# 48/48 [==============================] - 4s 83ms/step - loss: 7.3304e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.3873 - val_precision: 0.8436 - val_recall: 0.8856
# Epoch 189/200
# 48/48 [==============================] - 4s 85ms/step - loss: 0.0037 - precision: 0.9989 - recall: 0.9989 - val_loss: 2.4827 - val_precision: 0.8804 - val_recall: 0.8060
# Epoch 190/200
# 48/48 [==============================] - 4s 79ms/step - loss: 1.1976e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4934 - val_precision: 0.8190 - val_recall: 0.9005
# Epoch 191/200
# 48/48 [==============================] - 4s 80ms/step - loss: 0.0013 - precision: 0.9989 - recall: 1.0000 - val_loss: 2.8987 - val_precision: 0.8279 - val_recall: 0.8856
# Epoch 192/200
# 48/48 [==============================] - 4s 88ms/step - loss: 0.0065 - precision: 0.9989 - recall: 0.9989 - val_loss: 2.9611 - val_precision: 0.8089 - val_recall: 0.9055
# Epoch 193/200
# 48/48 [==============================] - 4s 76ms/step - loss: 2.1966e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.1646 - val_precision: 0.8629 - val_recall: 0.8458
# Epoch 194/200
# 48/48 [==============================] - 4s 88ms/step - loss: 0.0105 - precision: 0.9968 - recall: 0.9979 - val_loss: 2.3879 - val_precision: 0.8310 - val_recall: 0.8806
# Epoch 195/200
# 48/48 [==============================] - 4s 83ms/step - loss: 0.0093 - precision: 0.9979 - recall: 0.9989 - val_loss: 2.2929 - val_precision: 0.8318 - val_recall: 0.8856
# Epoch 196/200
# 48/48 [==============================] - 4s 84ms/step - loss: 5.6691e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4705 - val_precision: 0.8153 - val_recall: 0.9005
# Epoch 197/200
# 48/48 [==============================] - 4s 85ms/step - loss: 1.6995e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8112 - val_precision: 0.8265 - val_recall: 0.9005
# Epoch 198/200
# 48/48 [==============================] - 4s 78ms/step - loss: 5.4221e-04 - precision: 0.9989 - recall: 1.0000 - val_loss: 2.5915 - val_precision: 0.8465 - val_recall: 0.8507
# Epoch 199/200
# 48/48 [==============================] - 4s 79ms/step - loss: 0.0053 - precision: 0.9989 - recall: 0.9979 - val_loss: 2.6740 - val_precision: 0.8404 - val_recall: 0.8905
# Epoch 200/200
# 48/48 [==============================] - 4s 76ms/step - loss: 5.7389e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8021 - val_precision: 0.8333 - val_recall: 0.8955

# %%
X_test= preprocessig_data(X_test)
y_test = le.transform(y_test)

# %%
# Evaluacion del modelo con el conjunto de Test
score = model_base.evaluate(X_test, y_test)
print(f'Test loss: {score[0]}\nTest Precision: {score[1]}\nTest Recall: {score[2]}')
# Out:
# 13/13 [==============================] - 0s 23ms/step - loss: 1.9105 - precision: 0.9137 - recall: 0.8696
# Test loss: 1.9105467796325684
# Test Precision: 0.913705587387085
# Test Recall: 0.8695651888847351

# %%
import matplotlib.pyplot as plt
precision = history_base.history["precision"]
val_precision = history_base.history["val_precision"]
loss = history_base.history["loss"]
val_loss = history_base.history["val_loss"]
epochs = range(1, len(precision) + 1)
plt.plot(epochs, precision, "bo", label="Training precision")
plt.plot(epochs, val_precision, "b", label="Validation precision")
plt.title("Training and validation precision")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
def getRealPrediction(y_aux):
    y_predicted = np.zeros(len(y_aux))
    for i in range(len(y_aux)):
        if y_aux[i] >= 0.5:
            y_predicted[i] = 1
        else:
            y_predicted[i] = 0
    return y_predicted

# %%
from sklearn import metrics
import matplotlib.pyplot as plt

y_aux = model_base.predict(X_train)
y_predicted = getRealPrediction(y_aux)
confusion_matrix = metrics.confusion_matrix(y_train, y_predicted)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
print('Matriz de Confusión Train')
cm_display.plot()
plt.show()

y_aux = model_base.predict(X_test)
y_predicted = getRealPrediction(y_aux)
confusion_matrix = metrics.confusion_matrix(y_test, y_predicted)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
print('Matriz de Confusión Test')
cm_display.plot()
plt.show()
# Out:
# 60/60 [==============================] - 1s 19ms/step
# Matriz de Confusión Train
# 13/13 [==============================] - 0s 17ms/step
# Matriz de Confusión Test

# %% [markdown]
# ## Deploy del modelo: red convolucional

# %%
from tensorflow.keras.models import load_model
test_model = load_model("modelos/checkpoint_model3a")
IMG_SIZE = 50

def preprocessig_data(data):
    X = []
    for img_path in data:
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY) # Pasamos la imagen a escala de grises
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))/255.0 # normalizamos los pixeles de la imagen
        X.append(img)
    X = np.array(X)
    X = X.reshape((-1, IMG_SIZE, IMG_SIZE, 1)) #Hacemos un reshape de las imagenes
    return X

# %%
imagenPath = "data\\images\\image_13.jpg" # positiva
inputImage = preprocessig_data([imagenPath])
y_predicted = test_model(inputImage)
percentage = tf.gather(y_predicted, 0)[0].numpy()
real_val = getRealPrediction([percentage])[0]
print('percentage:',f'{round(percentage*100, 5)}%')
print('predicted:',real_val)
# Out:
# percentage: 73.9398%
# predicted: 1.0

# %%
imagenPath = "data\\images\\image_1054.jpg" # negativa
inputImage = preprocessig_data([imagenPath])
y_predicted = test_model(inputImage)
percentage = tf.gather(y_predicted, 0)[0].numpy()
real_val = getRealPrediction([percentage])[0]
print('percentage:',f'{round(percentage*100, 5)}%')
print('predicted:',real_val)
# Out:
# percentage: 1.90705%
# predicted: 0.0
